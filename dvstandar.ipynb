# %%
import math
import matplotlib.pyplot as plt

def calc_media_aritmetica(sum,n):
        media_aritmetica = sum / n
        return media_aritmetica

def calc_desv_estandar(x1,media_aritmetica,n):
    varianza = 0.00
    for i in range(0,30):
        varianza += (x1[i] - media_aritmetica)**2 / n
    desviacion = math.sqrt(varianza)
    return desviacion
        #

# %%
x1 = [20.24,19.21,20.68,20.87,18.6,19.16,20.34,20.03,20.31,19.68,21.11,21.06,20.54,21.42,20.94,19.92,20.94,19.92,21.43,20.72,20.66,20.3,21.86,20.8,20.62,20.72,21.47,21.38,21.46,21.51]
x2 = [1.01,1.03,1,1.02,0.96,1,0.99,0.98,0.99,1,1.03,0.98,1.01,1,1.01,1.04,1.03,1.04,1.02,1.01,1.02,1.03,1.03,1,1.03,1.03,1.08,1.06,1.01,1.02]
target = [14.94,14.8,16.16,15.04,14.82,14.31,15.05,15.84,13.16,13.54,14.07,13.2,14.59,16.46,15.16,16.56,16.29,15.64,16.72,15.42,14.31,15.34,16.72,13.92,14.42,15,16.54,17.41,14.35,16.15]

med_x1 = calc_media_aritmetica(sum(x1),30.00)
med_x2 = calc_media_aritmetica(sum(x2),30.00)
med_target = calc_media_aritmetica(sum(target),30.00)

bins= 1 +  math.log2(30)
ancho_target = (max(target) - min(target)) / bins

# %%
print(f"La sumatoria de x1 es: {sum(x1)}")
print(f"La sumatoria de x2 es: {sum(x2)}")
print(f"La sumatoria de target es: {sum(target)}\n")
asdadswkwfjiij


print(f"la media aritmetica de x1 es: {calc_media_aritmetica(sum(x1),30.00)}")
print(f"la media aritmetica de x2 es: {calc_media_aritmetica(sum(x2),30.00)}")
print(f"la media aritmetica de target es: {calc_media_aritmetica(sum(target),30.00)}\n")

print(f"la desviación estandar de x1 es: {calc_desv_estandar(x1,med_x1,30.00)}")
print(f"la desviación estandar de x2 es: {calc_desv_estandar(x2,med_x2,30.00)}")
print(f"la desviación estandar de target es: {calc_desv_estandar(target,med_target,30.00)}")
# Out:
# La sumatoria de x1 es: 617.9
# La sumatoria de x2 es: 30.46
# La sumatoria de target es: 455.93
#
# la media aritmetica de x1 es: 20.596666666666668
# la media aritmetica de x2 es: 1.0153333333333334
# la media aritmetica de target es: 15.197666666666667
#
# la desviación estandar de x1 es: 0.7574797393696778
# la desviación estandar de x2 es: 0.023907228102721497
# la desviación estandar de target es: 1.095480665684652

# %%
plt.scatter(x1, target, c='green', marker='o')

plt.xlabel('x1')
plt.ylabel('target')
plt.title('Grafico de dispersion')

plt.show()

# %%
plt.hist(target, bins=int(bins), color='green', edgecolor='black')

plt.xlabel('target')
plt.ylabel('frecuencia')
plt.title('Grafico de histograma')

plt.show()
